# %%
# %matplotlib inline
import csv
from __future__ import division
from datetime import datetime
from collections import Counter, defaultdict
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("turnstile_150328.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0328 = {}
for row in rows:
    raw_readings_0328.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150404.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0404 = {}
for row in rows:
    raw_readings_0404.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150411.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0411 = {}
for row in rows:
    raw_readings_0411.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150418.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0418 = {}
for row in rows:
    raw_readings_0418.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150425.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0425 = {}
for row in rows:
    raw_readings_0425.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150502.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0502 = {}
for row in rows:
    raw_readings_0502.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150509.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0509 = {}
for row in rows:
    raw_readings_0509.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150516.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0516 = {}
for row in rows:
    raw_readings_0516.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150523.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0523 = {}
for row in rows:
    raw_readings_0523.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150530.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0530 = {}
for row in rows:
    raw_readings_0530.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150606.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0606 = {}
for row in rows:
    raw_readings_0606.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
with open("turnstile_150613.csv") as f:
    reader = csv.reader(f)
    rows = [[cell.strip() for cell in row] for row in reader]
    
assert rows.pop(0) == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
                       'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
                       'EXITS']

raw_readings_0613 = {}
for row in rows:
    raw_readings_0613.setdefault(tuple(row[:5]), []).append(row[5:])

# %%
diclist_0328_0613 = [raw_readings_0328, raw_readings_0404, raw_readings_0411, raw_readings_0418, raw_readings_0425, raw_readings_0502, raw_readings_0509, raw_readings_0516, raw_readings_0523, raw_readings_0530, raw_readings_0606, raw_readings_0613]

# %%
def combine_dics(diclist):
    dic_combined = {}
    for dic in diclist:
        for key, val in dic.iteritems():
            if not key in dic_combined:
                dic_combined[key] = val
            else:
                dic_combined[key] = dic_combined[key] + val
    return dic_combined

data = combine_dics(diclist_0328_0613)

# %%
data.items()[0]
# Out:
# (('N549', 'R242', '00-00-01', '18 AVE', 'F'),
#  [['IND', '03/21/2015', '00:00:00', 'REGULAR', '0004846509', '0004972437'],
#   ['IND', '03/21/2015', '04:00:00', 'REGULAR', '0004846517', '0004972465'],
#   ['IND', '03/21/2015', '08:00:00', 'REGULAR', '0004846579', '0004972477'],
#   ['IND', '03/21/2015', '12:00:00', 'REGULAR', '0004846709', '0004972520'],
#   ['IND', '03/21/2015', '16:00:00', 'REGULAR', '0004846813', '0004972602'],
#   ['IND', '03/21/2015', '20:00:00', 'REGULAR', '0004846889', '0004972742'],
#   ['IND', '03/22/2015', '00:00:00', 'REGULAR', '0004846935', '0004972835'],
#   ['IND', '03/22/2015', '04:00:00', 'REGULAR', '0004846948', '0004972864'],
#   ['IND', '03/22/2015', '08:00:00', 'REGULAR', '0004846997', '0004972892'],
#   ['IND', '03/22/2015', '12:00:00', 'REGULAR', '0004847113', '0004972968'],
#   ['IND', '03/22/2015', '16:00:00', 'REGULAR', '0004847260', '0004973052'],
#   ['IND', '03/22/2015', '20:00:00', 'REGULAR', '0004847359', '0004973207'],
# ...

# %%
datetime_cumulative = {turnstile: [(datetime.strptime(date + time,
                                                      '%m/%d/%Y%X'),
                                    int(in_cumulative))
                                   for _, date, time,
                                       _, in_cumulative, _ in rows]
                       for turnstile, rows in data.items()}

# %%
for rows in datetime_cumulative.values()[:3]:
    print rows
# Out:
# [(datetime.datetime(2015, 3, 21, 0, 0), 4846509), (datetime.datetime(2015, 3, 21, 4, 0), 4846517), (datetime.datetime(2015, 3, 21, 8, 0), 4846579), (datetime.datetime(2015, 3, 21, 12, 0), 4846709), (datetime.datetime(2015, 3, 21, 16, 0), 4846813), (datetime.datetime(2015, 3, 21, 20, 0), 4846889), (datetime.datetime(2015, 3, 22, 0, 0), 4846935), (datetime.datetime(2015, 3, 22, 4, 0), 4846948), (datetime.datetime(2015, 3, 22, 8, 0), 4846997), (datetime.datetime(2015, 3, 22, 12, 0), 4847113), (datetime.datetime(2015, 3, 22, 16, 0), 4847260), (datetime.datetime(2015, 3, 22, 20, 0), 4847359), (datetime.datetime(2015, 3, 23, 0, 0), 4847408), (datetime.datetime(2015, 3, 23, 4, 0), 4847416), (datetime.datetime(2015, 3, 23, 8, 0), 4847628), (datetime.datetime(2015, 3, 23, 12, 0), 4847895), (datetime.datetime(2015, 3, 23, 16, 0), 4848049), (datetime.datetime(2015, 3, 23, 20, 0), 4848241), (datetime.datetime(2015, 3, 24, 0, 0), 4848297), (datetime.datetime(2015, 3, 24, 4, 0), 4848304), (datetim
# ...

# %%
for key, row in datetime_cumulative.iteritems():
    datetime_cumulative[key] = sorted(row)

# %%
for rows in datetime_cumulative.values():
    assert rows == sorted(rows)

# %%
datetime_count_times = {turnstile: [[rows[i][0],
                                     rows[i+1][1] - rows[i][1],
                                     rows[i+1][0] - rows[i][0]]
                                    for i in range(len(rows) - 1)]
                        for turnstile, rows in datetime_cumulative.items()}

# %%
all_counts = [count for rows in datetime_count_times.values() for _, count, _ in rows]
all_counts.sort()
print all_counts[-100:]
# Out:
# [5051, 5188, 5541, 5655, 5681, 6014, 6305, 6413, 6586, 6608, 6638, 6811, 7073, 7074, 7179, 7500, 7596, 7654, 7779, 7818, 7833, 7899, 8588, 8610, 8628, 8890, 9566, 9574, 10230, 11728, 11865, 12514, 12982, 13596, 15248, 21585, 32239, 40637, 41825, 47146, 51712, 51712, 87975, 94566, 94642, 94699, 94885, 100188, 113308, 113343, 241641, 280665, 280665, 407303, 407345, 447244, 447792, 448280, 540997, 574928, 920245, 920490, 920838, 920974, 921000, 943123, 3259795, 8553144, 11120236, 23621940, 50331614, 50331648, 51735018, 79040925, 83567603, 83614107, 83814175, 83886041, 113346685, 116981760, 117439432, 167770787, 169801557, 200550914, 217267268, 233966580, 300838435, 367622558, 367654298, 367655512, 434527962, 436524900, 685288285, 951648553, 1036156801, 1153104117, 1395619898, 1541995760, 1654488698, 1941360122]

# %%
print all_counts[:15000]
# Out:
# [-1874197078, -1654410902, -1403809425, -752058474, -671287970, -451130794, -267997619, -234412148, -134479872, -116970030, -50331648, -33554473, -17093717, -13592378, -13466666, -8909849, -8552573, -8551746, -7586280, -5983249, -5702468, -5396672, -4575853, -4241382, -3535096, -3104217, -3090944, -2878675, -2687195, -2471433, -2161616, -2044984, -1716093, -1548235, -1425128, -1367465, -1343818, -1305908, -1275874, -1273028, -1262354, -1178379, -1153210, -1105692, -1104044, -1029076, -980532, -920968, -920842, -920727, -920126, -920058, -894619, -730128, -698496, -669448, -608977, -574902, -540573, -531698, -508092, -501033, -461078, -454483, -450654, -447792, -447715, -447192, -406974, -405708, -378547, -349577, -330831, -321111, -299511, -280665, -280665, -280610, -268006, -259786, -257818, -247327, -241321, -220199, -219843, -219531, -192465, -185040, -179341, -164557, -159265, -139224, -113308, -113249, -103578, -101507, -95046, -94699, -94642, -94566, -94282, -92595, -91820, -87
# ...

# %%
all_times = [duration.total_seconds() / 60 / 60
             for rows in datetime_count_times.values()
             for _, _, duration in rows]
print Counter(all_times).most_common(10)
# Out:
# [(4.0, 2123470), (4.2, 129286), (8.0, 2574), (4.433333333333334, 2046), (0.02222222222222222, 1300), (0.022500000000000003, 671), (0.23333333333333334, 264), (0.02277777777777778, 150), (4.199722222222222, 146), (3.999722222222222, 111)]

# %%
datetime_counts = {turnstile: [(time, count)
                               for (time, count, _) in rows
                               if 0 <= count <= 5000]
                   for turnstile, rows in datetime_count_times.items()}

# %%
all_good_counts = [count for rows in datetime_counts.values() for _, count in rows]
print len(all_good_counts) / len(all_counts)
# Out:
# 0.994220146272

# %%
all_good_counts.sort()
print all_good_counts[-5:]
# Out:
# [4730, 4831, 4920, 4957, 4966]

# %%
print all_good_counts[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
day_counts = {}
for turnstile, rows in datetime_counts.items():
    by_day = {}
    for time, count in rows:
        day = time.date()
        by_day[day] = by_day.get(day, 0) + count
    day_counts[turnstile] = sorted(by_day.items())

# %%
day_counts.items()[0]
# Out:
# (('N549', 'R242', '00-00-01', '18 AVE', 'F'),
#  [(datetime.date(2015, 3, 21), 426),
#   (datetime.date(2015, 3, 22), 473),
#   (datetime.date(2015, 3, 23), 889),
#   (datetime.date(2015, 3, 24), 831),
#   (datetime.date(2015, 3, 25), 847),
#   (datetime.date(2015, 3, 26), 826),
#   (datetime.date(2015, 3, 27), 807),
#   (datetime.date(2015, 3, 28), 476),
#   (datetime.date(2015, 3, 29), 445),
#   (datetime.date(2015, 3, 30), 816),
#   (datetime.date(2015, 3, 31), 832),
#   (datetime.date(2015, 4, 1), 829),
#   (datetime.date(2015, 4, 2), 784),
#   (datetime.date(2015, 4, 3), 583),
#   (datetime.date(2015, 4, 4), 407),
#   (datetime.date(2015, 4, 5), 334),
#   (datetime.date(2015, 4, 6), 826),
#   (datetime.date(2015, 4, 7), 725),
#   (datetime.date(2015, 4, 8), 716),
#   (datetime.date(2015, 4, 9), 643),
#   (datetime.date(2015, 4, 10), 560),
#   (datetime.date(2015, 4, 11), 445),
#   (datetime.date(2015, 4, 12), 259),
#   (datetime.date(2015, 4, 13), 932),
# ...

# %%
dictlist =[]
for key, value in day_counts.iteritems():
    vallist = []
    for k, v in value:
        val = [k,v]
        vallist.append(val)
    temp = [key, vallist]
    dictlist.append(temp)
    
dictlist[:3]
# Out:
# [[('N549', 'R242', '00-00-01', '18 AVE', 'F'),
#   [[datetime.date(2015, 3, 21), 426],
#    [datetime.date(2015, 3, 22), 473],
#    [datetime.date(2015, 3, 23), 889],
#    [datetime.date(2015, 3, 24), 831],
#    [datetime.date(2015, 3, 25), 847],
#    [datetime.date(2015, 3, 26), 826],
#    [datetime.date(2015, 3, 27), 807],
#    [datetime.date(2015, 3, 28), 476],
#    [datetime.date(2015, 3, 29), 445],
#    [datetime.date(2015, 3, 30), 816],
#    [datetime.date(2015, 3, 31), 832],
#    [datetime.date(2015, 4, 1), 829],
#    [datetime.date(2015, 4, 2), 784],
#    [datetime.date(2015, 4, 3), 583],
#    [datetime.date(2015, 4, 4), 407],
#    [datetime.date(2015, 4, 5), 334],
#    [datetime.date(2015, 4, 6), 826],
#    [datetime.date(2015, 4, 7), 725],
#    [datetime.date(2015, 4, 8), 716],
#    [datetime.date(2015, 4, 9), 643],
#    [datetime.date(2015, 4, 10), 560],
#    [datetime.date(2015, 4, 11), 445],
#    [datetime.date(2015, 4, 12), 259],
#    [datetime.date(2015, 4, 13), 932],
# ...

# %%
data_station = {}
data_station = defaultdict(list)
for l in dictlist:
    key = l[0]
    value = l[1]
    data_station[key].append(value)
    
sorted(data_station.items())[0]
# Out:
# (('A002', 'R051', '02-00-00', 'LEXINGTON AVE', 'NQR456'),
#  [[[datetime.date(2015, 3, 21), 992],
#    [datetime.date(2015, 3, 22), 704],
#    [datetime.date(2015, 3, 23), 1709],
#    [datetime.date(2015, 3, 24), 1770],
#    [datetime.date(2015, 3, 25), 1937],
#    [datetime.date(2015, 3, 26), 1851],
#    [datetime.date(2015, 3, 27), 1998],
#    [datetime.date(2015, 3, 28), 1105],
#    [datetime.date(2015, 3, 29), 840],
#    [datetime.date(2015, 3, 30), 1810],
#    [datetime.date(2015, 3, 31), 1683],
#    [datetime.date(2015, 4, 1), 1825],
#    [datetime.date(2015, 4, 2), 1919],
#    [datetime.date(2015, 4, 3), 1479],
#    [datetime.date(2015, 4, 4), 61],
#    [datetime.date(2015, 4, 5), 0],
#    [datetime.date(2015, 4, 6), 1639],
#    [datetime.date(2015, 4, 7), 1710],
#    [datetime.date(2015, 4, 8), 1704],
#    [datetime.date(2015, 4, 9), 1769],
#    [datetime.date(2015, 4, 10), 1786],
#    [datetime.date(2015, 4, 11), 928],
#    [datetime.date(2015, 4, 12), 657],
# ...

# %%
for key, value in data_station.iteritems():
    dd = defaultdict(int)
    for index, val in enumerate(value):
        for i, v in enumerate(val):
            date = v[0]
            dd[date] += v[1]
    data_station[key] = dd

# %%
sorted(data_station.items())[0]
# Out:
# (('A002', 'R051', '02-00-00', 'LEXINGTON AVE', 'NQR456'),
#  defaultdict(int,
#              {datetime.date(2015, 3, 21): 992,
#               datetime.date(2015, 3, 22): 704,
#               datetime.date(2015, 3, 23): 1709,
#               datetime.date(2015, 3, 24): 1770,
#               datetime.date(2015, 3, 25): 1937,
#               datetime.date(2015, 3, 26): 1851,
#               datetime.date(2015, 3, 27): 1998,
#               datetime.date(2015, 3, 28): 1105,
#               datetime.date(2015, 3, 29): 840,
#               datetime.date(2015, 3, 30): 1810,
#               datetime.date(2015, 3, 31): 1683,
#               datetime.date(2015, 4, 1): 1825,
#               datetime.date(2015, 4, 2): 1919,
#               datetime.date(2015, 4, 3): 1479,
#               datetime.date(2015, 4, 4): 61,
#               datetime.date(2015, 4, 5): 0,
#               datetime.date(2015, 4, 6): 1639,
#               datetime.date(2015, 4, 7): 1710,
# ...

# %%
type(data_station.items()[0])
# Out:
# tuple

# %%
data_list = []
for key, value in data_station.iteritems():
    for k, val in value.iteritems():
        templist = [(key[3], key[4]), k, val]
        data_list.append(templist)

# %%
data_list[:5]
# Out:
# [[('18 AVE', 'F'), datetime.date(2015, 6, 1), 757],
#  [('18 AVE', 'F'), datetime.date(2015, 4, 28), 792],
#  [('18 AVE', 'F'), datetime.date(2015, 5, 2), 430],
#  [('18 AVE', 'F'), datetime.date(2015, 6, 2), 743],
#  [('18 AVE', 'F'), datetime.date(2015, 4, 2), 784]]

# %%
df = pd.DataFrame(data_list, columns = ['station', 'day', 'count'])

# %%
df.head()
# Out:
#        station         day  count
# 0  (18 AVE, F)  2015-06-01    757
# 1  (18 AVE, F)  2015-04-28    792
# 2  (18 AVE, F)  2015-05-02    430
# 3  (18 AVE, F)  2015-06-02    743
# 4  (18 AVE, F)  2015-04-02    784

# %%
df['weekday'] = np.NaN
for i in range(len(df)):
    df['weekday'][i] = df['day'][i].weekday()

# %%
df.head()
# Out:
#        station         day  count  weekday
# 0  (18 AVE, F)  2015-06-01    757        0
# 1  (18 AVE, F)  2015-04-28    792        1
# 2  (18 AVE, F)  2015-05-02    430        5
# 3  (18 AVE, F)  2015-06-02    743        1
# 4  (18 AVE, F)  2015-04-02    784        3

# %%
grouped_station = df.groupby('station')

# %%
grouped_station_stats = grouped_station['count'].agg({'total traffic': np.sum, 'average': np.mean, 'std': np.std})

# %%
grouped_station.describe()
# Out:
#                                       count     weekday
# station
# (1 AVE, L)               count   840.000000  840.000000
#                          mean   1982.080952    3.000000
#                          std    1746.930541    2.001192
#                          min       0.000000    0.000000
#                          25%     647.250000    1.000000
#                          50%    1434.500000    3.000000
#                          75%    3204.250000    5.000000
#                          max    6397.000000    6.000000
# (103 ST, 1)              count   504.000000  504.000000
#                          mean   1912.029762    3.000000
#                          std     886.601554    2.001987
#                          min       0.000000    0.000000
#                          25%    1503.500000    1.000000
#                          50%    1996.000000    3.000000
#                          75%    2409.500000    5.000000
#                          max    3685.000000    6.000000
# ...

# %%
grouped_station_stats
# Out:
#                                    std      average  total traffic
# station
# (1 AVE, L)                 1746.930541  1982.080952        1664948
# (103 ST, 1)                 886.601554  1912.029762         963663
# (103 ST, 6)                 887.203292  1850.753968         932780
# (103 ST, BC)                693.392851  1477.507937         372332
# (103 ST-CORONA, 7)          932.827088  2035.810847        1539073
# (104 ST, JZ)                273.210313   685.261905         172686
# (110 ST, 6)                1159.148694  1989.021825        1002467
# (110 ST-CATHEDRL, 1)       1115.235102  1689.433673         993387
# (110 ST-CPN, 23)            611.632758  1534.797619         773538
# (111 ST, 7)                 467.453142  2081.542857         874248
# (111 ST, J)                 286.927760   598.083333         200956
# (116 ST, 23)                474.376792  1438.511905         966680
# (116 ST, 6)                 875.205425  1859.786885        1247917
# ...

# %%
toptotal = grouped_station_stats.sort('total traffic', ascending=False)[0:10]
topavg = grouped_station_stats.sort('average', ascending=False)[0:10]
print toptotal
print topavg
# Out:
#                                         std      average  total traffic
# station
# (42 ST-GRD CNTRL, 4567S)        1855.125774  2121.219086       11047309
# (34 ST-HERALD SQ, BDFMNQR)      1624.732577  2036.278177        9069583
# (42 ST-TIMES SQ, 1237ACENQRS)   1338.284983  1970.646051        6786905
# (34 ST-PENN STA, ACE)           1074.043072  1288.133703        6271923
# (42 ST-PA BUS TE, ACENQRS1237)  1361.718844  1860.006122        6076640
# (14 ST-UNION SQ, LNQR456)       1735.644318  2579.400641        5633411
# (86 ST, 456)                    1832.156568  2748.366342        5078981
# (MAIN ST, 7)                    1483.012802  2010.768959        4560424
# (59 ST-COLUMBUS, ABCD1)         1785.567216  1993.774691        4521881
# (47-50 ST-ROCK, BDFM)           1190.594903  1415.118386        4279318
#                                    std      average  total traffic
# station
# (96 ST, 6)                 1693.030996  3898.039683        1964612
# ...

# %%
top = toptotal['total traffic'].plot(kind='barh', legend = True).invert_yaxis()
top

# %%
grouped_weekday = df.groupby('weekday')

# %%
grouped_weekday.head()
# Out:
#         station         day  count  weekday
# 0   (18 AVE, F)  2015-06-01    757        0
# 1   (18 AVE, F)  2015-04-28    792        1
# 2   (18 AVE, F)  2015-05-02    430        5
# 3   (18 AVE, F)  2015-06-02    743        1
# 4   (18 AVE, F)  2015-04-02    784        3
# 5   (18 AVE, F)  2015-03-26    826        3
# 6   (18 AVE, F)  2015-05-16    433        5
# 7   (18 AVE, F)  2015-06-06    376        5
# 8   (18 AVE, F)  2015-03-24    831        1
# 9   (18 AVE, F)  2015-04-06    826        0
# 10  (18 AVE, F)  2015-06-08    779        0
# 11  (18 AVE, F)  2015-03-30    816        0
# 12  (18 AVE, F)  2015-05-13    783        2
# 13  (18 AVE, F)  2015-04-04    407        5
# 14  (18 AVE, F)  2015-04-19    439        6
# 15  (18 AVE, F)  2015-05-25    415        0
# 16  (18 AVE, F)  2015-03-28    476        5
# 17  (18 AVE, F)  2015-05-15    787        4
# 18  (18 AVE, F)  2015-04-10    560        4
# 19  (18 AVE, F)  2015-04-17    886        4
# ...

# %%
sorted(data_station.keys(), key = lambda tup: tup[3])[500:2000]
# Out:
# [('R130', 'R321', '01-00-01', '18 ST', '1'),
#  ('R129', 'R321', '00-00-00', '18 ST', '1'),
#  ('R130', 'R321', '01-06-01', '18 ST', '1'),
#  ('R130', 'R321', '01-00-00', '18 ST', '1'),
#  ('R130', 'R321', '01-06-00', '18 ST', '1'),
#  ('N007A', 'R174', '00-00-01', '181 ST', 'A'),
#  ('R183', 'R260', '00-00-03', '181 ST', '1'),
#  ('R183', 'R260', '00-00-04', '181 ST', '1'),
#  ('R183', 'R260', '00-00-02', '181 ST', '1'),
#  ('R183', 'R260', '00-00-00', '181 ST', '1'),
#  ('R183', 'R260', '00-00-01', '181 ST', '1'),
#  ('N009', 'R174', '01-00-01', '181 ST', 'A'),
#  ('N009', 'R174', '01-00-00', '181 ST', 'A'),
#  ('N007A', 'R174', '00-00-00', '181 ST', 'A'),
#  ('N009', 'R174', '01-00-02', '181 ST', 'A'),
#  ('N007A', 'R174', '00-00-02', '181 ST', 'A'),
#  ('N215', 'R237', '00-00-02', '182-183 ST', 'BD'),
#  ('N215', 'R237', '00-00-00', '182-183 ST', 'BD'),
#  ('N215', 'R237', '00-00-01', '182-183 ST', 'BD'),
#  ('R288', 'R275', '00-00-00', '183 ST', '4'),
# ...

# %%
WTC = defaultdict(list)
for key, value in data_station.iteritems():
    if key[3] == 'PATH WTC':
        for k, v in value.iteritems():
            tempkey = k
            val = v
            WTC[tempkey].append(val)

# %%
WTC
# Out:
# defaultdict(list,
#             {datetime.date(2015, 3, 21): [212,
#               34,
#               719,
#               858,
#               1265,
#               9,
#               97,
#               14,
#               56,
#               1264,
#               68,
#               530,
#               42,
#               3,
#               850,
#               816,
#               3,
#               160,
#               889,
#               594,
#               359,
#               608,
#               133,
#               830,
#               325,
#               958,
#               27],
#              datetime.date(2015, 3, 22): [203,
#               44,
#               543,
#               741,
#               1038,
#               10,
#               78,
#               9,
#               59,
#               1021,
#               51,
#               410,
#               31,
#               2,
#               690,
#               677,
#               3,
# ...

# %%
WTCday = defaultdict(int)
for key, value in WTC.iteritems():
    for i, val in enumerate(value):
        date = key
        WTCday[date] += val

# %%
WTCday
# Out:
# defaultdict(int,
#             {datetime.date(2015, 3, 21): 11723,
#              datetime.date(2015, 3, 22): 9399,
#              datetime.date(2015, 3, 23): 48983,
#              datetime.date(2015, 3, 24): 50389,
#              datetime.date(2015, 3, 25): 49668,
#              datetime.date(2015, 3, 26): 48705,
#              datetime.date(2015, 3, 27): 45143,
#              datetime.date(2015, 3, 28): 12052,
#              datetime.date(2015, 3, 29): 9307,
#              datetime.date(2015, 3, 30): 49174,
#              datetime.date(2015, 3, 31): 50607,
#              datetime.date(2015, 4, 1): 50699,
#              datetime.date(2015, 4, 2): 50514,
#              datetime.date(2015, 4, 3): 32318,
#              datetime.date(2015, 4, 4): 12468,
#              datetime.date(2015, 4, 5): 9249,
#              datetime.date(2015, 4, 6): 47164,
#              datetime.date(2015, 4, 7): 49671,
#              datetime.date(2015, 4, 8): 48441,
# ...

# %%
WTClist = []
for key, value in WTCday.iteritems():
    temp = (key, value)
    WTClist.append(temp)

# %%
WTCdates, WTCcounts = zip(*sorted(WTClist))

# %%
np.sum(WTCcounts)
print np.mean(WTCcounts)
print np.std(WTCcounts)
# Out:
# 38502.1785714
# 17247.6757828

# %%
plt.figure(figsize=(10,3))
plt.plot(WTCdates,WTCcounts)

# %%
Timesq = defaultdict(list)
for key, value in data_station.iteritems():
    if key[3] == '42 ST-TIMES SQ':
        for k, v in value.iteritems():
            tempkey = k
            val = v
            Timesq[tempkey].append(val)

# %%
TSday = defaultdict(int)
for key, value in Timesq.iteritems():
    for i, val in enumerate(value):
        date = key
        TSday[date] += val

# %%
TSlist = []
for key, value in TSday.iteritems():
    temp = (key, value)
    TSlist.append(temp)

# %%
sorted(TSlist)
# Out:
# [(datetime.date(2015, 3, 21), 64456),
#  (datetime.date(2015, 3, 22), 52137),
#  (datetime.date(2015, 3, 23), 92254),
#  (datetime.date(2015, 3, 24), 97734),
#  (datetime.date(2015, 3, 25), 101326),
#  (datetime.date(2015, 3, 26), 100927),
#  (datetime.date(2015, 3, 27), 102890),
#  (datetime.date(2015, 3, 28), 65250),
#  (datetime.date(2015, 3, 29), 52516),
#  (datetime.date(2015, 3, 30), 95353),
#  (datetime.date(2015, 3, 31), 102693),
#  (datetime.date(2015, 4, 1), 107486),
#  (datetime.date(2015, 4, 2), 109074),
#  (datetime.date(2015, 4, 3), 95689),
#  (datetime.date(2015, 4, 4), 74190),
#  (datetime.date(2015, 4, 5), 60973),
#  (datetime.date(2015, 4, 6), 101712),
#  (datetime.date(2015, 4, 7), 106238),
#  (datetime.date(2015, 4, 8), 110224),
#  (datetime.date(2015, 4, 9), 106635),
#  (datetime.date(2015, 4, 10), 104433),
#  (datetime.date(2015, 4, 11), 76965),
#  (datetime.date(2015, 4, 12), 59210),
#  (datetime.date(2015, 4, 13), 93989),
# ...

# %%
TSdates, TScounts = zip(*sorted(TSlist))
print np.mean(TScounts)
print np.std(TScounts)
# Out:
# 91106.75
# 19055.3261408

# %%
plt.figure(figsize=(10,3))
plt.plot(TSdates,TScounts)
plt.ylabel('Total Traffic')

# %%
datetime_counts.items()[0]
# Out:
# (('N549', 'R242', '00-00-01', '18 AVE', 'F'),
#  [(datetime.datetime(2015, 3, 21, 0, 0), 8),
#   (datetime.datetime(2015, 3, 21, 4, 0), 62),
#   (datetime.datetime(2015, 3, 21, 8, 0), 130),
#   (datetime.datetime(2015, 3, 21, 12, 0), 104),
#   (datetime.datetime(2015, 3, 21, 16, 0), 76),
#   (datetime.datetime(2015, 3, 21, 20, 0), 46),
#   (datetime.datetime(2015, 3, 22, 0, 0), 13),
#   (datetime.datetime(2015, 3, 22, 4, 0), 49),
#   (datetime.datetime(2015, 3, 22, 8, 0), 116),
#   (datetime.datetime(2015, 3, 22, 12, 0), 147),
#   (datetime.datetime(2015, 3, 22, 16, 0), 99),
#   (datetime.datetime(2015, 3, 22, 20, 0), 49),
#   (datetime.datetime(2015, 3, 23, 0, 0), 8),
#   (datetime.datetime(2015, 3, 23, 4, 0), 212),
#   (datetime.datetime(2015, 3, 23, 8, 0), 267),
#   (datetime.datetime(2015, 3, 23, 12, 0), 154),
#   (datetime.datetime(2015, 3, 23, 16, 0), 192),
#   (datetime.datetime(2015, 3, 23, 20, 0), 56),
#   (datetime.datetime(2015, 3, 24, 0, 0), 7),
# ...

# %%
datetime_counts.items()[0]
# Out:
# (('N549', 'R242', '00-00-01', '18 AVE', 'F'),
#  [(datetime.datetime(2015, 3, 21, 0, 0), 8),
#   (datetime.datetime(2015, 3, 21, 4, 0), 62),
#   (datetime.datetime(2015, 3, 21, 8, 0), 130),
#   (datetime.datetime(2015, 3, 21, 12, 0), 104),
#   (datetime.datetime(2015, 3, 21, 16, 0), 76),
#   (datetime.datetime(2015, 3, 21, 20, 0), 46),
#   (datetime.datetime(2015, 3, 22, 0, 0), 13),
#   (datetime.datetime(2015, 3, 22, 4, 0), 49),
#   (datetime.datetime(2015, 3, 22, 8, 0), 116),
#   (datetime.datetime(2015, 3, 22, 12, 0), 147),
#   (datetime.datetime(2015, 3, 22, 16, 0), 99),
#   (datetime.datetime(2015, 3, 22, 20, 0), 49),
#   (datetime.datetime(2015, 3, 23, 0, 0), 8),
#   (datetime.datetime(2015, 3, 23, 4, 0), 212),
#   (datetime.datetime(2015, 3, 23, 8, 0), 267),
#   (datetime.datetime(2015, 3, 23, 12, 0), 154),
#   (datetime.datetime(2015, 3, 23, 16, 0), 192),
#   (datetime.datetime(2015, 3, 23, 20, 0), 56),
#   (datetime.datetime(2015, 3, 24, 0, 0), 7),
# ...

# %%
timelist = []
for key, value in datetime_counts.iteritems():
    for index, tup in enumerate(value):
        temp = [key[3], tup[0], tup[1]]
        timelist.append(temp)

# %%
timelist[:5]
# Out:
# [['18 AVE', datetime.datetime(2015, 3, 21, 0, 0), 8],
#  ['18 AVE', datetime.datetime(2015, 3, 21, 4, 0), 62],
#  ['18 AVE', datetime.datetime(2015, 3, 21, 8, 0), 130],
#  ['18 AVE', datetime.datetime(2015, 3, 21, 12, 0), 104],
#  ['18 AVE', datetime.datetime(2015, 3, 21, 16, 0), 76]]

# %%
TStimeseries = [[x[1],x[2]] for x in timelist if x[0] == '42 ST-TIMES SQ']

# %%
TSdf = pd.DataFrame(TStimeseries, columns = ['time', 'count'])

# %%
TSdf
# Out:
#                      time  count
# 0     2015-03-21 00:00:00     51
# 1     2015-03-21 04:00:00     20
# 2     2015-03-21 08:00:00     72
# 3     2015-03-21 12:00:00    205
# 4     2015-03-21 16:00:00    231
# 5     2015-03-21 20:00:00    123
# 6     2015-03-22 00:00:00     55
# 7     2015-03-22 04:00:00     22
# 8     2015-03-22 08:00:00     47
# 9     2015-03-22 12:00:00    147
# 10    2015-03-22 16:00:00    171
# 11    2015-03-22 20:00:00    108
# 12    2015-03-23 00:00:00     19
# 13    2015-03-23 04:00:00     33
# 14    2015-03-23 08:00:00    282
# 15    2015-03-23 12:00:00    482
# 16    2015-03-23 16:00:00   1440
# 17    2015-03-23 20:00:00    280
# 18    2015-03-24 00:00:00     25
# 19    2015-03-24 04:00:00     32
# 20    2015-03-24 08:00:00    151
# 21    2015-03-24 12:00:00    389
# 22    2015-03-24 16:00:00   1448
# 23    2015-03-24 20:00:00    379
# 24    2015-03-25 00:00:00     34
# 25    2015-03-25 04:00:00     39
# 26    2015-03-25 08:00:00    178
# ...

# %%
TStimeseries = TSdf.groupby('time')['count'].agg({'total': np.sum})

# %%
TStimeseries[13:20].plot().set_ylabel('Total Traffic')

# %%
TSListweekday = [[x[0].weekday(), x[1]] for x in TSlist]

# %%
TSListweekday
# Out:
# [[1, 100543],
#  [5, 69192],
#  [1, 103569],
#  [3, 109074],
#  [1, 105823],
#  [3, 100927],
#  [2, 107486],
#  [5, 73058],
#  [1, 97734],
#  [0, 101712],
#  [0, 95353],
#  [2, 106832],
#  [5, 74190],
#  [6, 54857],
#  [5, 65250],
#  [4, 108126],
#  [1, 98613],
#  [4, 104433],
#  [4, 102031],
#  [2, 110365],
#  [5, 70833],
#  [2, 110224],
#  [3, 104494],
#  [4, 100019],
#  [0, 97172],
#  [6, 64643],
#  [0, 100016],
#  [1, 101243],
#  [5, 71600],
#  [1, 102718],
#  [6, 59210],
#  [0, 95419],
#  [0, 100607],
#  [3, 104438],
#  [6, 52137],
#  [5, 68074],
#  [4, 106852],
#  [1, 101500],
#  [6, 59771],
#  [4, 106109],
#  [6, 56198],
#  [2, 104651],
#  [4, 102890],
#  [2, 110576],
#  [4, 95689],
#  [6, 51427],
#  [4, 85387],
#  [6, 60574],
#  [4, 106495],
#  [5, 65844],
#  [0, 56334],
#  [2, 109393],
#  [0, 98714],
#  [5, 69114],
#  [6, 52516],
#  [1, 103777],
#  [3, 108859],
#  [6, 60973],
#  [3, 103728],
#  [3, 107689],
#  [3, 107038],
#  [5, 76965],
#  [2, 101326],
#  [2, 106315],
# ...

# %%
TSweekdaycount = Counter()
for l in TSListweekday:
    TSweekdaycount[l[0]] += l[1]
    
TSweekdaycount
# Out:
# Counter({0: 1117363,
#          1: 1228614,
#          2: 1280587,
#          3: 1273609,
#          4: 1226553,
#          5: 840524,
#          6: 685717})

# %%
Weekdays = TSweekdaycount.keys()
Weekdaycounts = TSweekdaycount.values()

# %%
Weekday = ['Mon', 'Tues', 'Weds', 'Thur', 'Fri', 'Sat', 'Sun']
pos = np.arange(len(Weekday))
width = 1.0

ax = plt.axes()
ax.set_ylabel('Total Traffic')
ax.set_xticks(pos + width / 2)
ax.set_xticklabels(Weekday)

plt.bar(Weekdays, Weekdaycounts)
# Out:
# <Container object of 7 artists>

# %%
PStimeseries = [[x[1],x[2]] for x in timelist if x[0] == '34 ST-PENN STA']

# %%
PSdf = pd.DataFrame(PStimeseries, columns = ['time', 'count'])

# %%
PStimeseries = PSdf.groupby('time')['count'].agg({'total': np.sum})

# %%
PSPlotday = PStimeseries[47:60]

# %%
PSPlotday[PSPlotday['total'] > 1000].plot().set_ylabel('Total Traffic')
